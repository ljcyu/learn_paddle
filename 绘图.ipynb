# %%
import paddle
import numpy as np
# 使图像在当前窗口显示
# %matplotlib inline
import matplotlib.pyplot as plt
x = np.arange(0,100,0.1,dtype='float32')
plt.plot(x,x*x)
plt.show()

# %%
import math
x = np.arange(0,10,0.1,dtype='float32')
plt.plot(x,np.cos(x))
plt.show()
